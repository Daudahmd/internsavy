# %% [markdown]
# #Import libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
sns.set()

# %% [markdown]
# #Read data

# %%
df = pd.read_csv("/content/Admission_Predict_Ver1.1.csv")
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
# ...

# %%
df.corr
# Out:
# <bound method DataFrame.corr of      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
final = df.drop(['Serial No.'],axis = 'columns')
final
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 495        332          108                  5  4.5   4.0  9.02         1
# 496        337          117                  5  5.0   5.0  9.87         1
# 497        330          120                  5  4.5   5.0  9.56         1
# 498        312          103                  4  4.0   5.0  8.43         0
# 499        327          113                  4  4.5   4.5  9.04         0
#
#      Chance of Admit
# 0                0.92
# 1                0.76
# ...

# %% [markdown]
# #Check Nan Values

# %%
final.isna().sum()
# Out:
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %% [markdown]
# #Plot a graph

# %%
plt.xlabel('CGPA')
plt.ylabel('Chance of Admit ')
plt.scatter(final.CGPA, final['Chance of Admit '])

# %%
plt.xlabel('GRE Score')
plt.ylabel('Chance of Admit ')
plt.scatter(final['GRE Score'], final['Chance of Admit '],color = 'red')

# %%
x = final.drop(['Chance of Admit '], axis = 'columns')
y = final['Chance of Admit ']

# %% [markdown]
# #Import Model

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()

# %% [markdown]
# #Split data

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.score(x_test,y_test)
# Out:
# 0.8471705483179176

# %%
reg.predict(x_test)
# Out:
# array([0.96162482, 0.56379215, 0.71418973, 0.67997007, 0.760797  ,
#        0.84925334, 0.6698919 , 0.71393279, 0.93359418, 0.69853962,
#        0.9665992 , 0.77876298, 0.55749665, 0.75658165, 0.84654849,
#        0.74243099, 0.75019369, 0.43589758, 0.68267554, 0.58917103,
#        0.69996212, 0.73893955, 0.90192379, 0.66564468, 0.596855  ,
#        0.71163531, 0.61088383, 0.86193752, 0.59957564, 0.87845763,
#        0.68293515, 0.70900833, 0.76410195, 0.84918197, 0.91537963,
#        0.73439082, 0.57006264, 0.80084304, 0.6341686 , 0.51435476,
#        0.90589007, 0.9049955 , 0.86612738, 0.72645977, 0.73922617,
#        0.73992181, 0.95902521, 0.53955541, 0.61709489, 0.84974576,
#        0.59889398, 0.59231892, 0.99715062, 0.85469334, 0.90143243,
#        0.6336039 , 0.52536066, 0.83195572, 0.63789123, 0.64254989,
#        0.69386756, 0.94628483, 0.80761415, 0.6288341 , 0.61962503,
#        0.84784925, 0.97143936, 0.71703066, 0.62369759, 0.90256801,
# ...

# %%
reg.predict([[345,120,5,4.5,3.2,8.23]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([0.7801092])
